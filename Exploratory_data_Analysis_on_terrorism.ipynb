# %% [markdown]
# ## **Importing the Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Loading the Dataset**

# %%
df=pd.read_csv('globalterrorism.csv',encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
df.shape
# Out:
# (16581, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.658100e+04  16581.000000  16581.000000  16581.000000  16581.000000
# mean   1.978029e+11   1977.966045      6.201978     15.155962      0.020445
# std    3.266916e+08      3.270107      3.415697      8.949768      0.141521
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.976092e+11   1976.000000      3.000000      7.000000      0.000000
# 50%    1.979051e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.980121e+11   1980.000000      9.000000     23.000000      0.000000
# max    1.982072e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  16581.000000  16581.000000  15975.000000  15975.000000  16581.000000
# mean     183.120258      5.524878     27.875821    -28.932087      1.253543
# std      170.441089      3.372000     22.109249     55.936993      0.905089
# min        4.000000      1.000000    -45.867889   -157.818968      1.000000
# 25%       69.000000      2.000000     13.692880    -86.600964      1.000000
# 50%      110.000000      8.000000     35.689125     -6.443767      1.000000
# 75%      217.000000      8.000000     43.291618      9.991586      1.000000
# max      605.000000     12.000000     64.837778    172.636225      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  4.170000e+02          1.0  8.800000e+01           1.0
# mean   ...  3.793429e+06      20000.0  1.351280e+06           0.0
# std    ...  4.932135e+07          NaN  4.853561e+06           NaN
# min    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 25%    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 50%    ...  0.000000e+00      20000.0  7.050000e+04           0.0
# 75%    ...  4.150000e+05      20000.0  7.250000e+05           0.0
# max    ...  1.000000e+09      20000.0  4.100000e+07           0.0
#
#        hostkidoutcome   nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count      638.000000  486.000000  16580.000000  16580.000000  16580.000000
# mean         2.888715    8.341564     -3.738118     -3.693667      0.263450
# std          1.280881   28.437426      4.552678      4.601334      0.657961
# min          2.000000  -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000    1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000    1.000000      0.000000      0.000000      0.000000
# 75%          4.000000    2.000000      0.000000      0.000000      1.000000
# max          7.000000  215.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  16580.000000
# mean      -2.668034
# std        4.561017
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 81 columns]

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 16576  198207150003   1982       7    15        NaN         0        NaN
# 16577  198207150004   1982       7    15        NaN         0        NaN
# 16578  198207150005   1982       7    15        NaN         0        NaN
# 16579  198207150006   1982       7    15        NaN         0        NaN
# 16580  198207160001   1982       7    16        NaN         0        NaN
#
#        country         country_txt  region  ... addnotes scite1 scite2  \
# 0           58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1          130              Mexico       1  ...      NaN    NaN    NaN
# 2          160         Philippines       5  ...      NaN    NaN    NaN
# 3           78              Greece       8  ...      NaN    NaN    NaN
# 4          101               Japan       4  ...      NaN    NaN    NaN
# ...        ...                 ...     ...  ...      ...    ...    ...
# 16576       69              France       8  ...      NaN    NaN    NaN
# 16577       69              France       8  ...      NaN    NaN    NaN
# 16578       98               Italy       8  ...      NaN    NaN    NaN
# 16579      159                Peru       3  ...      NaN    NaN    NaN
# 16580      185               Spain       8  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0         NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 1         NaN      PGIS      0.0       1.0      1.0     1.0      NaN
# 2         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 4         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# ...       ...       ...      ...       ...      ...     ...      ...
# 16576     NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 16577     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 16578     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 16579     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 16580     NaN       NaN      NaN       NaN      NaN     NaN      NaN
#
# [16581 rows x 135 columns]>

# %% [markdown]
# ### **To find if Data contains any missing value**

# %%
df
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 16576  198207150003   1982       7    15        NaN         0        NaN
# 16577  198207150004   1982       7    15        NaN         0        NaN
# 16578  198207150005   1982       7    15        NaN         0        NaN
# 16579  198207150006   1982       7    15        NaN         0        NaN
# 16580  198207160001   1982       7    16        NaN         0        NaN
#
#        country         country_txt  region  ... addnotes scite1 scite2  \
# 0           58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1          130              Mexico       1  ...      NaN    NaN    NaN
# 2          160         Philippines       5  ...      NaN    NaN    NaN
# 3           78              Greece       8  ...      NaN    NaN    NaN
# 4          101               Japan       4  ...      NaN    NaN    NaN
# ...        ...                 ...     ...  ...      ...    ...    ...
# 16576       69              France       8  ...      NaN    NaN    NaN
# 16577       69              France       8  ...      NaN    NaN    NaN
# 16578       98               Italy       8  ...      NaN    NaN    NaN
# 16579      159                Peru       3  ...      NaN    NaN    NaN
# 16580      185               Spain       8  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0         NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 1         NaN      PGIS      0.0       1.0      1.0     1.0      NaN
# 2         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 4         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# ...       ...       ...      ...       ...      ...     ...      ...
# 16576     NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 16577     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 16578     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 16579     NaN      PGIS     -9.0      -9.0      0.0    -9.0      NaN
# 16580     NaN       NaN      NaN       NaN      NaN     NaN      NaN
#
# [16581 rows x 135 columns]

# %%
df.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    16560
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       15876
# Length: 135, dtype: int64

# %% [markdown]
# ## **Filtering the required columns for Exploratory Analysis**

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','extended':'Extended','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'Latitude','longitude':'Longitude','attacktype1_txt':'AttackType','nkill':'Killed','nwound':'Wounded','summary':'Summary','target1':'Target'},inplace=True)

# %%
df=df[['Year','Month','Day','Extended','Country','Region','State','City','Latitude','Longitude','AttackType','Killed','Wounded','Summary','Target']]

# %%
df.describe()
# Out:
#                Year         Month           Day      Extended      Latitude  \
# count  16581.000000  16581.000000  16581.000000  16581.000000  15975.000000
# mean    1977.966045      6.201978     15.155962      0.020445     27.875821
# std        3.270107      3.415697      8.949768      0.141521     22.109249
# min     1970.000000      0.000000      0.000000      0.000000    -45.867889
# 25%     1976.000000      3.000000      7.000000      0.000000     13.692880
# 50%     1979.000000      6.000000     15.000000      0.000000     35.689125
# 75%     1980.000000      9.000000     23.000000      0.000000     43.291618
# max     1986.000000     12.000000     31.000000      1.000000     64.837778
#
#           Longitude        Killed       Wounded
# count  15975.000000  13830.000000  12406.000000
# mean     -28.932087      1.400362      1.313074
# std       55.936993      6.684258      8.044576
# min     -157.818968      0.000000      0.000000
# 25%      -86.600964      0.000000      0.000000
# 50%       -6.443767      0.000000      0.000000
# 75%        9.991586      1.000000      0.000000
# max      172.636225    422.000000    300.000000

# %%
df.head()
# Out:
#    Year  Month  Day  Extended             Country  \
# 0  1970      7    2         0  Dominican Republic
# 1  1970      0    0         0              Mexico
# 2  1970      1    0         0         Philippines
# 3  1970      1    0         0              Greece
# 4  1970      1    0         0               Japan
#
#                         Region    State           City   Latitude   Longitude  \
# 0  Central America & Caribbean      NaN  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#                        AttackType  Killed  Wounded Summary  \
# 0                   Assassination     1.0      0.0     NaN
# 1     Hostage Taking (Kidnapping)     0.0      0.0     NaN
# 2                   Assassination     1.0      0.0     NaN
# 3               Bombing/Explosion     NaN      NaN     NaN
# 4  Facility/Infrastructure Attack     NaN      NaN     NaN
#
#                     Target
# 0             Julio Guzman
# 1  Nadine Chaval, daughter
# 2                 Employee
# 3             U.S. Embassy
# 4           U.S. Consulate

# %%
df.tail()
# Out:
#        Year  Month  Day  Extended Country          Region           State  \
# 16576  1982      7   15         0  France  Western Europe         Corsica
# 16577  1982      7   15         0  France  Western Europe         Corsica
# 16578  1982      7   15         0   Italy  Western Europe        Campania
# 16579  1982      7   15         0    Peru   South America        Ayacucho
# 16580  1982      7   16         0   Spain  Western Europe  Basque Country
#
#                     City   Latitude  Longitude         AttackType  Killed  \
# 16576       L'Ile-Rousse  42.636510   8.937046  Bombing/Explosion     0.0
# 16577            Ajaccio  41.930607   8.742907  Bombing/Explosion     0.0
# 16578             Naples  40.840097  14.251636      Assassination     2.0
# 16579  Ayacucho district -14.318840 -74.378173      Assassination     1.0
# 16580            Vitoria  42.849640  -2.692359  Bombing/Explosion     NaN
#
#        Wounded Summary                                             Target
# 16576      0.0     NaN                                 German owned hotel
# 16577      0.0     NaN                                        restaurants
# 16578      0.0     NaN  Antonio Ammaturo, 57, Head of Mobile Police Force
# 16579      0.0     NaN                                           Civilian
# 16580      NaN     NaN                                        Police Bldg

# %%
print("Country with most terrorist attacks:", df.Country.value_counts().idxmax())
print("Region with most terrorist attacks:", df.Region.value_counts().idxmax())
print("State with most terrorist attacks:", df.State.value_counts().idxmax())
print("City with most terrorist attacks:", df.City.value_counts().idxmax())
# Out:
# Country with most terrorist attacks: El Salvador
# Region with most terrorist attacks: Western Europe
# State with most terrorist attacks: Northern Ireland
# City with most terrorist attacks: Belfast

# %% [markdown]
# ## **Correlation between different features**

# %%
feature_corr=df.corr()
print(feature_corr)
# Out:
#                Year     Month       Day  Extended  Latitude  Longitude  \
# Year       1.000000 -0.083935 -0.014265 -0.056886 -0.280117  -0.025792
# Month     -0.083935  1.000000  0.006187  0.015787 -0.013284  -0.019874
# Day       -0.014265  0.006187  1.000000 -0.000184  0.015753   0.011642
# Extended  -0.056886  0.015787 -0.000184  1.000000 -0.079776  -0.014184
# Latitude  -0.280117 -0.013284  0.015753 -0.079776  1.000000   0.376778
# Longitude -0.025792 -0.019874  0.011642 -0.014184  0.376778   1.000000
# Killed     0.092982 -0.002974 -0.008019 -0.015005 -0.070344  -0.034255
# Wounded    0.027087  0.012092  0.006551 -0.018858  0.019506   0.118875
#
#              Killed   Wounded
# Year       0.092982  0.027087
# Month     -0.002974  0.012092
# Day       -0.008019  0.006551
# Extended  -0.015005 -0.018858
# Latitude  -0.070344  0.019506
# Longitude -0.034255  0.118875
# Killed     1.000000  0.205058
# Wounded    0.205058  1.000000

# %% [markdown]
# ## Barplot

# %%
plt.style.use('seaborn')
plt.subplots(figsize=(14,5))
plt.xticks(rotation=90)
x_years=df['Year'].unique()
y_counts=df['Year'].value_counts(dropna=False).sort_index()
sns.barplot(x=x_years,y=y_counts)
plt.xlabel('Year of attacks')
plt.ylabel('No. of attacks')
plt.title('No. of terrorist activities every year')
# Out:
# Text(0.5, 1.0, 'No. of terrorist activities every year')

# %% [markdown]
# ## Histogram

# %%
df.hist(figsize=(20,14))
plt.show()

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x=df['Year'])
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ## Violinplot

# %%
sns.violinplot(x=df['Year'])
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ## Terrorist Activites by Country

# %%
plt.style.use('seaborn')
plt.subplots(figsize=(14,5))
plt.xticks(rotation=90)
sns.barplot(x=df['Country'].value_counts()[:15].index,y=df['Country'].value_counts()[:15].values)
plt.xlabel('Country')
plt.ylabel('No. of attacks')
plt.title('No. of terrorist activities by country')
plt.show()

# %% [markdown]
# ## Terrorist Activities by Region

# %%
plt.style.use('seaborn')
plt.subplots(figsize=(14,5))
plt.xticks(rotation=90)
sns.barplot(x=df['Region'].value_counts()[:15].index,y=df['Region'].value_counts()[:15].values)
plt.xlabel('Region')
plt.ylabel('No. of attacks')
plt.title('No. of terrorist activities by Region')
plt.show()

# %% [markdown]
# ## No. of Deaths every year

# %%
plt.style.use('seaborn')
plt.subplots(figsize=(14,5))
plt.xticks(rotation=45)
sns.barplot(x=df['Killed'].value_counts()[1:15].index,y=df['Killed'].value_counts()[1:15].values)
plt.xlabel('Count of deaths')
plt.ylabel('No. of deaths corr. to each count')
plt.title('No. of deaths')
plt.show()

# %% [markdown]
# ## No. of Injuries every year

# %%
plt.style.use('seaborn')
plt.subplots(figsize=(14,5))
plt.xticks(rotation=45)
sns.barplot(x=df['Wounded'].value_counts()[1:15].index,y=df['Wounded'].value_counts()[1:15].values)
plt.xlabel('Count of injuries')
plt.ylabel('No. of injuries corr. to each count')
plt.title('No. of injuries')
plt.show()

# %% [markdown]
# ## Different types of terrorist attacks

# %%
plt.style.use('seaborn')
plt.subplots(figsize=(14,5))
plt.xticks(rotation=90)
sns.barplot(x=df['AttackType'].value_counts().index,y=df['AttackType'].value_counts().values)
plt.xlabel('Type of Attacks')
plt.ylabel('No. of attacks')
plt.title('Different Types of Terrorist Attacks')
plt.show()

# %% [markdown]
# ## Targets of Terrorist Attacks

# %%
plt.style.use('seaborn')
plt.subplots(figsize=(14,5))
plt.xticks(rotation=90)
sns.barplot(x=df['Target'].value_counts()[:15].index,y=df['Target'].value_counts()[:15].values)
plt.xlabel('Target of Attacks')
plt.ylabel('No. of attacks')
plt.title('Targets of Terrorist Attacks')
plt.show()

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# * **Country with most terrorist attacks: El Salvador**
# * **Region with most terrorist attacks: Western Europe**
# * **State with most terrorist attacks: Baghdad**
# * **City with most terrorist attacks: Unknown**
# * **Most type of the terrorist attacks: Bombing/Explosion**
# * **Year with most terrorist attacks**: **1980**
# * **Most of the targets of terrorist attacks: Military**
#   **Unit**
